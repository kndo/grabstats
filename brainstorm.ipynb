# %%
import yaml

from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-76-93e73321e3a3> in <module>
# ----> 1 import yaml
#       2
#       3 from bs4 import BeautifulSoup
#       4 import numpy as np
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'yaml'

# %%
def get_requested_schedule(date):
    """
    :param date: a string with format 'YYYY-MM-DD' or 'YYYY-MM'

    :return schedule: a pd.DataFrame containing game info for games
                      played on the requested date, either a day or month
    """

    # Get year and month from date
    year = arrow.get(date).datetime.strftime('%Y')           # e.g. 2018
    month = arrow.get(date).datetime.strftime('%B').lower()  # e.g. january

    # BBallRef takes the season year as the calendar year when the Playoffs
    # are played; therefore, the 2017-2018 season is the 2018 season
    if month in ['october', 'november', 'december']:
        year = str(int(year) + 1)  # Increment year

    monthly_schedule = get_monthly_schedule(year, month)

    # If year year, month, and day given in date, return daily schedule
    if len(date.split('-')) == 3:
        return monthly_schedule.query('DATE == @date').reset_index(drop=True)
    return schedule  # monthly schedule

# %%
year = '2019'
month = 'january'
url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
page = requests.get(url).text
soup = BeautifulSoup(page, 'lxml')

# %%
class MonthlySchedule:
    def __init__(self, year, month):
        self.year = year
        self.month = month
        self.url = url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
        page = requests.get(url).text
        self.soup = BeautifulSoup(page, 'lxml')
        
        self._get_schedule()

        
    def _get_col(self, tag, data_stat, pop_title=False):
        result = self.soup.find_all(tag, {'data-stat': data_stat})
        if pop_title:
            result.pop(0)
        return [row.a.text if row.a else row.text for row in result]

    
    def _get_col_box_score_url(self):
        result = self.soup.find_all('td', {'data-stat': 'box_score_text'})
        return [row.a.get('href') if row.a else '' for row in result]

    
    def _get_schedule(self):
        col_game_date = self._get_col('th', 'date_game', pop_title=True)
        col_road_team = self._get_col('td', 'visitor_team_name')
        col_road_pts = self._get_col('td', 'visitor_pts')
        col_home_team = self._get_col('td', 'home_team_name')
        col_home_pts = self._get_col('td', 'home_pts')
        col_box_score_url = self._get_col_box_score_url()
        
        schedule = {
            'DATE':          col_game_date,
            'ROAD_TEAM':     col_road_team,
            'ROAD_PTS':      col_road_pts,
            'HOME_TEAM':     col_home_team,
            'HOME_PTS':      col_home_pts,
            'BOX_SCORE_URL': col_box_score_url,
        }
        
        self.schedule = pd.DataFrame(schedule)
        self.schedule = self.schedule.replace('', np.nan)
        self.schedule = self.schedule.dropna(how='any')
        
        self._abbrev_team_names()
        self._reorder_cols()
        self._complete_box_score_url()
    
    
    def _abbrev_team_names(self):
        self.schedule['ROAD_TEAM_ABBR'] = \
                self.schedule['ROAD_TEAM'].apply(team_name_abbr)
        self.schedule['HOME_TEAM_ABBR'] = \
                self.schedule['HOME_TEAM'].apply(team_name_abbr)
            
    
    def _reorder_cols(self):
        reordered_cols = ['DATE',
            'ROAD_TEAM', 'ROAD_TEAM_ABBR', 'ROAD_PTS',
            'HOME_TEAM', 'HOME_TEAM_ABBR', 'HOME_PTS',
            'BOX_SCORE_URL'    
        ]
        self.schedule = self.schedule[reordered_cols]
        
        
    def _complete_box_score_url(self):
        BBALLREF = 'https://www.basketball-reference.com'
        self.schedule['BOX_SCORE_URL'] = \
                self.schedule['BOX_SCORE_URL'].apply(lambda x: BBALLREF + x)

# %%
ms = MonthlySchedule('2019', 'april')
ms.schedule
# Out:
# DATE 79
# ROAD_TEAM 79
# ROAD_PTS 79
# HOME_TEAM 79
# HOME_PTS 79
# BOX_SCORE_URL 79
#                  DATE               ROAD_TEAM ROAD_PTS  \
# 0    Mon, Apr 1, 2019              Miami Heat      105
# 1    Mon, Apr 1, 2019         Milwaukee Bucks      131
# 2    Mon, Apr 1, 2019      Philadelphia 76ers      102
# 3    Mon, Apr 1, 2019         Detroit Pistons      102
# 4    Mon, Apr 1, 2019  Portland Trail Blazers      132
# 5    Mon, Apr 1, 2019           Chicago Bulls      105
# 6    Mon, Apr 1, 2019     Cleveland Cavaliers      113
# 7    Mon, Apr 1, 2019           Orlando Magic      109
# 8    Mon, Apr 1, 2019       Charlotte Hornets      102
# 9    Tue, Apr 2, 2019          Denver Nuggets      102
# 10   Tue, Apr 2, 2019      Los Angeles Lakers      103
# 11   Tue, Apr 2, 2019         Houston Rockets      130
# 12   Tue, Apr 2, 2019           Atlanta Hawks      111
# 13   Wed, Apr 3, 2019      Philadelphia 76ers      122
# 14   Wed, Apr 3, 2019         Toronto Raptors      115
# 15   Wed, Apr 3, 2019  Minnesota Timberwolves      110
# 16   Wed, Apr 3, 2019       San Antonio Spurs       85
# 17   Wed, Apr 3, 2019          Indiana Pacers      108
# 18   Wed, Apr 3, 2019         Houston Rockets      135
# 19   Wed, Apr 3, 2019          Boston Celtics      112
# 20   Wed, Apr 3, 2019       Charlotte Hornets      115
# 21   Wed, Apr 3, 2019         New York Knicks      100
# 22   Wed, Apr 3, 2019               Utah Jazz      118
# 23   Wed, Apr 3, 2019       Memphis Grizzlies       89
# 24   Wed, Apr 3, 2019           Chicago Bulls      115
# 25   Thu, Apr 4, 2019   Golden State Warriors      108
# 26   Thu, Apr 4, 2019         Milwaukee Bucks      128
# 27   Thu, Apr 4, 2019     Cleveland Cavaliers      104
# 28   Fri, Apr 5, 2019         Toronto Raptors      111
# 29   Fri, Apr 5, 2019       Memphis Grizzlies      122
# ..                ...                     ...      ...
# 49   Sun, Apr 7, 2019               Utah Jazz
# 50   Sun, Apr 7, 2019        Dallas Mavericks
# 51   Sun, Apr 7, 2019           Atlanta Hawks
# 52   Sun, Apr 7, 2019   Oklahoma City Thunder
# 53   Sun, Apr 7, 2019      Washington Wizards
# 54   Sun, Apr 7, 2019          Denver Nuggets
# 55   Sun, Apr 7, 2019    New Orleans Pelicans
# 56   Sun, Apr 7, 2019              Miami Heat
# 57   Tue, Apr 9, 2019         New York Knicks
# 58   Tue, Apr 9, 2019       Charlotte Hornets
# 59   Tue, Apr 9, 2019            Phoenix Suns
# 60   Tue, Apr 9, 2019       Memphis Grizzlies
# 61   Tue, Apr 9, 2019  Portland Trail Blazers
# 62   Tue, Apr 9, 2019      Philadelphia 76ers
# 63   Tue, Apr 9, 2019         Toronto Raptors
# 64   Tue, Apr 9, 2019   Golden State Warriors
# 65   Tue, Apr 9, 2019         Houston Rockets
# 66   Tue, Apr 9, 2019          Denver Nuggets
# 67   Tue, Apr 9, 2019          Boston Celtics
# 68  Wed, Apr 10, 2019          Indiana Pacers
# 69  Wed, Apr 10, 2019              Miami Heat
# 70  Wed, Apr 10, 2019           Orlando Magic
# 71  Wed, Apr 10, 2019  Minnesota Timberwolves
# 72  Wed, Apr 10, 2019               Utah Jazz
# 73  Wed, Apr 10, 2019   Golden State Warriors
# 74  Wed, Apr 10, 2019   Oklahoma City Thunder
# 75  Wed, Apr 10, 2019         Detroit Pistons
# 76  Wed, Apr 10, 2019           Chicago Bulls
# 77  Wed, Apr 10, 2019        Sacramento Kings
# 78  Wed, Apr 10, 2019        Dallas Mavericks
#
#                  HOME_TEAM HOME_PTS                 BOX_SCORE_URL
# 0           Boston Celtics      110  /boxscores/201904010BOS.html
# 1            Brooklyn Nets      121  /boxscores/201904010BRK.html
# 2         Dallas Mavericks      122  /boxscores/201904010DAL.html
# 3           Indiana Pacers      111  /boxscores/201904010IND.html
# 4   Minnesota Timberwolves      122  /boxscores/201904010MIN.html
# 5          New York Knicks      113  /boxscores/201904010NYK.html
# 6             Phoenix Suns      122  /boxscores/201904010PHO.html
# 7          Toronto Raptors      121  /boxscores/201904010TOR.html
# 8                Utah Jazz      111  /boxscores/201904010UTA.html
# 9    Golden State Warriors      116  /boxscores/201904020GSW.html
# 10   Oklahoma City Thunder      119  /boxscores/201904020OKC.html
# 11        Sacramento Kings      105  /boxscores/201904020SAC.html
# 12       San Antonio Spurs      117  /boxscores/201904020SAS.html
# 13           Atlanta Hawks      130  /boxscores/201904030ATL.html
# 14           Brooklyn Nets      105  /boxscores/201904030BRK.html
# 15        Dallas Mavericks      108  /boxscores/201904030DAL.html
# 16          Denver Nuggets      113  /boxscores/201904030DEN.html
# 17         Detroit Pistons       89  /boxscores/201904030DET.html
# 18    Los Angeles Clippers      103  /boxscores/201904030LAC.html
# 19              Miami Heat      102  /boxscores/201904030MIA.html
# 20    New Orleans Pelicans      109  /boxscores/201904030NOP.html
# 21           Orlando Magic      114  /boxscores/201904030ORL.html
# 22            Phoenix Suns       97  /boxscores/201904030PHO.html
# 23  Portland Trail Blazers      116  /boxscores/201904030POR.html
# 24      Washington Wizards      114  /boxscores/201904030WAS.html
# 25      Los Angeles Lakers       90  /boxscores/201904040LAL.html
# 26      Philadelphia 76ers      122  /boxscores/201904040PHI.html
# 27        Sacramento Kings      117  /boxscores/201904040SAC.html
# 28       Charlotte Hornets      113  /boxscores/201904050CHO.html
# 29        Dallas Mavericks      112  /boxscores/201904050DAL.html
# ..                     ...      ...                           ...
# 49      Los Angeles Lakers
# 50       Memphis Grizzlies
# 51         Milwaukee Bucks
# 52  Minnesota Timberwolves
# 53         New York Knicks
# 54  Portland Trail Blazers
# 55        Sacramento Kings
# 56         Toronto Raptors
# 57           Chicago Bulls
# 58     Cleveland Cavaliers
# 59        Dallas Mavericks
# 60         Detroit Pistons
# 61      Los Angeles Lakers
# 62              Miami Heat
# 63  Minnesota Timberwolves
# 64    New Orleans Pelicans
# 65   Oklahoma City Thunder
# 66               Utah Jazz
# 67      Washington Wizards
# 68           Atlanta Hawks
# 69           Brooklyn Nets
# 70       Charlotte Hornets
# 71          Denver Nuggets
# 72    Los Angeles Clippers
# 73       Memphis Grizzlies
# 74         Milwaukee Bucks
# 75         New York Knicks
# 76      Philadelphia 76ers
# 77  Portland Trail Blazers
# 78       San Antonio Spurs
#
# [79 rows x 6 columns]

# %%
ms.schedule
# Out:
#                  DATE               ROAD_TEAM ROAD_PTS  \
# 0    Mon, Apr 1, 2019              Miami Heat      105
# 1    Mon, Apr 1, 2019         Milwaukee Bucks      131
# 2    Mon, Apr 1, 2019      Philadelphia 76ers      102
# 3    Mon, Apr 1, 2019         Detroit Pistons      102
# 4    Mon, Apr 1, 2019  Portland Trail Blazers      132
# 5    Mon, Apr 1, 2019           Chicago Bulls      105
# 6    Mon, Apr 1, 2019     Cleveland Cavaliers      113
# 7    Mon, Apr 1, 2019           Orlando Magic      109
# 8    Mon, Apr 1, 2019       Charlotte Hornets      102
# 9    Tue, Apr 2, 2019          Denver Nuggets      102
# 10   Tue, Apr 2, 2019      Los Angeles Lakers      103
# 11   Tue, Apr 2, 2019         Houston Rockets      130
# 12   Tue, Apr 2, 2019           Atlanta Hawks      111
# 13   Wed, Apr 3, 2019      Philadelphia 76ers      122
# 14   Wed, Apr 3, 2019         Toronto Raptors      115
# 15   Wed, Apr 3, 2019  Minnesota Timberwolves      110
# 16   Wed, Apr 3, 2019       San Antonio Spurs       85
# 17   Wed, Apr 3, 2019          Indiana Pacers      108
# 18   Wed, Apr 3, 2019         Houston Rockets      135
# 19   Wed, Apr 3, 2019          Boston Celtics      112
# 20   Wed, Apr 3, 2019       Charlotte Hornets      115
# 21   Wed, Apr 3, 2019         New York Knicks      100
# 22   Wed, Apr 3, 2019               Utah Jazz      118
# 23   Wed, Apr 3, 2019       Memphis Grizzlies       89
# 24   Wed, Apr 3, 2019           Chicago Bulls      115
# 25   Thu, Apr 4, 2019   Golden State Warriors      108
# 26   Thu, Apr 4, 2019         Milwaukee Bucks      128
# 27   Thu, Apr 4, 2019     Cleveland Cavaliers      104
# 28   Fri, Apr 5, 2019         Toronto Raptors      111
# 29   Fri, Apr 5, 2019       Memphis Grizzlies      122
# ..                ...                     ...      ...
# 49   Sun, Apr 7, 2019               Utah Jazz
# 50   Sun, Apr 7, 2019        Dallas Mavericks
# 51   Sun, Apr 7, 2019           Atlanta Hawks
# 52   Sun, Apr 7, 2019   Oklahoma City Thunder
# 53   Sun, Apr 7, 2019      Washington Wizards
# 54   Sun, Apr 7, 2019          Denver Nuggets
# 55   Sun, Apr 7, 2019    New Orleans Pelicans
# 56   Sun, Apr 7, 2019              Miami Heat
# 57   Tue, Apr 9, 2019         New York Knicks
# 58   Tue, Apr 9, 2019       Charlotte Hornets
# 59   Tue, Apr 9, 2019            Phoenix Suns
# 60   Tue, Apr 9, 2019       Memphis Grizzlies
# 61   Tue, Apr 9, 2019  Portland Trail Blazers
# 62   Tue, Apr 9, 2019      Philadelphia 76ers
# 63   Tue, Apr 9, 2019         Toronto Raptors
# 64   Tue, Apr 9, 2019   Golden State Warriors
# 65   Tue, Apr 9, 2019         Houston Rockets
# 66   Tue, Apr 9, 2019          Denver Nuggets
# 67   Tue, Apr 9, 2019          Boston Celtics
# 68  Wed, Apr 10, 2019          Indiana Pacers
# 69  Wed, Apr 10, 2019              Miami Heat
# 70  Wed, Apr 10, 2019           Orlando Magic
# 71  Wed, Apr 10, 2019  Minnesota Timberwolves
# 72  Wed, Apr 10, 2019               Utah Jazz
# 73  Wed, Apr 10, 2019   Golden State Warriors
# 74  Wed, Apr 10, 2019   Oklahoma City Thunder
# 75  Wed, Apr 10, 2019         Detroit Pistons
# 76  Wed, Apr 10, 2019           Chicago Bulls
# 77  Wed, Apr 10, 2019        Sacramento Kings
# 78  Wed, Apr 10, 2019        Dallas Mavericks
#
#                  HOME_TEAM HOME_PTS                 BOX_SCORE_URL
# 0           Boston Celtics      110  /boxscores/201904010BOS.html
# 1            Brooklyn Nets      121  /boxscores/201904010BRK.html
# 2         Dallas Mavericks      122  /boxscores/201904010DAL.html
# 3           Indiana Pacers      111  /boxscores/201904010IND.html
# 4   Minnesota Timberwolves      122  /boxscores/201904010MIN.html
# 5          New York Knicks      113  /boxscores/201904010NYK.html
# 6             Phoenix Suns      122  /boxscores/201904010PHO.html
# 7          Toronto Raptors      121  /boxscores/201904010TOR.html
# 8                Utah Jazz      111  /boxscores/201904010UTA.html
# 9    Golden State Warriors      116  /boxscores/201904020GSW.html
# 10   Oklahoma City Thunder      119  /boxscores/201904020OKC.html
# 11        Sacramento Kings      105  /boxscores/201904020SAC.html
# 12       San Antonio Spurs      117  /boxscores/201904020SAS.html
# 13           Atlanta Hawks      130  /boxscores/201904030ATL.html
# 14           Brooklyn Nets      105  /boxscores/201904030BRK.html
# 15        Dallas Mavericks      108  /boxscores/201904030DAL.html
# 16          Denver Nuggets      113  /boxscores/201904030DEN.html
# 17         Detroit Pistons       89  /boxscores/201904030DET.html
# 18    Los Angeles Clippers      103  /boxscores/201904030LAC.html
# 19              Miami Heat      102  /boxscores/201904030MIA.html
# 20    New Orleans Pelicans      109  /boxscores/201904030NOP.html
# 21           Orlando Magic      114  /boxscores/201904030ORL.html
# 22            Phoenix Suns       97  /boxscores/201904030PHO.html
# 23  Portland Trail Blazers      116  /boxscores/201904030POR.html
# 24      Washington Wizards      114  /boxscores/201904030WAS.html
# 25      Los Angeles Lakers       90  /boxscores/201904040LAL.html
# 26      Philadelphia 76ers      122  /boxscores/201904040PHI.html
# 27        Sacramento Kings      117  /boxscores/201904040SAC.html
# 28       Charlotte Hornets      113  /boxscores/201904050CHO.html
# 29        Dallas Mavericks      112  /boxscores/201904050DAL.html
# ..                     ...      ...                           ...
# 49      Los Angeles Lakers
# 50       Memphis Grizzlies
# 51         Milwaukee Bucks
# 52  Minnesota Timberwolves
# 53         New York Knicks
# 54  Portland Trail Blazers
# 55        Sacramento Kings
# 56         Toronto Raptors
# 57           Chicago Bulls
# 58     Cleveland Cavaliers
# 59        Dallas Mavericks
# 60         Detroit Pistons
# 61      Los Angeles Lakers
# 62              Miami Heat
# 63  Minnesota Timberwolves
# 64    New Orleans Pelicans
# 65   Oklahoma City Thunder
# 66               Utah Jazz
# 67      Washington Wizards
# 68           Atlanta Hawks
# 69           Brooklyn Nets
# 70       Charlotte Hornets
# 71          Denver Nuggets
# 72    Los Angeles Clippers
# 73       Memphis Grizzlies
# 74         Milwaukee Bucks
# 75         New York Knicks
# 76      Philadelphia 76ers
# 77  Portland Trail Blazers
# 78       San Antonio Spurs
#
# [79 rows x 6 columns]

# %%
def get_monthly_schedule(year, month):
    """
    :param year: a string, e.g. 2018
    :param month: a string, e.g. january

    :return schedule: a pd.DataFrame containing game info for the month
    """

# %%
def get_monthly_schedule(year, month):
    """
    :param year: a string, e.g. 2018
    :param month: a string, e.g. january

    :return schedule: a pd.DataFrame containing game info for the month
    """

    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_games-{month}.html'
    page = requests.get(url)
    tree = html.fromstring(page.content)

    game_date = tree.xpath('//*[@data-stat="date_game"]/a/text()')

    road_team = tree.xpath('//*[@data-stat="visitor_team_name"]/a/text()')
    road_pts = tree.xpath('//*[@data-stat="visitor_pts"]/text()')
    road_pts.pop(0)  # Remove column name

    home_team = tree.xpath('//*[@data-stat="home_team_name"]/a/text()')
    home_pts = tree.xpath('//*[@data-stat="home_pts"]/text()')
    home_pts.pop(0)  # Remove column name

    box_score_url = tree.xpath('//*[@data-stat="box_score_text"]/a/@href')

    schedule = {
        'DATE':           game_date,
        'ROAD_TEAM':      road_team,
        'ROAD_PTS':       road_pts,
        'HOME_TEAM':      home_team,
        'HOME_PTS':       home_pts,
        'BOX_SCORE_URL':  box_score_url,
    }

    # Create a dictionary with different length columns (Series) that is
    # suitable for a DataFrame
    schedule = dict([ (k, pd.Series(v)) for k, v in schedule.items() ])
    schedule = pd.DataFrame(schedule)
    schedule.dropna(how='any', inplace=True)
    schedule['ROAD_TM'] = schedule['ROAD_TEAM'].map(team_name_abbrev)
    schedule['HOME_TM'] = schedule['HOME_TEAM'].map(team_name_abbrev)
    schedule = schedule[['DATE', 'ROAD_TEAM', 'ROAD_TM', 'ROAD_PTS',
                         'HOME_TEAM', 'HOME_TM', 'HOME_PTS', 'BOX_SCORE_URL']]

    BBALLREF = 'https://www.basketball-reference.com'
    schedule['BOX_SCORE_URL'] = \
            schedule['BOX_SCORE_URL'].apply(lambda x: BBALLREF + x)

    def format_date(date):
        return arrow.get(date, 'ddd, MMM D, YYYY').datetime.strftime('%Y-%m-%d')

    schedule['DATE'] = schedule['DATE'].apply(format_date)

    return schedule
